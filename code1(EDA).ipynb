# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import math
import seaborn as sns
import os
from collections import Counter
import sklearn
from sklearn.decomposition import PCA
from sklearn import metrics, preprocessing, neighbors, cluster
from sklearn import cluster
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
plt.rcParams['figure.figsize'] = (10, 6)
plt.style.use('ggplot')
# Create color maps
from matplotlib.colors import ListedColormap
cmap = ListedColormap(["#e41a1c","#984ea3","#a65628","#377eb8","#ffff33","#4daf4a","#ff7f00"])
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("FinalDF.csv")
df
# Out:
#                        Player  Overall Score  Potential Score  Market Value  \
# 0                Lionel Messi             94               97    78000000.0
# 1           Cristiano Ronaldo             92               92    55500000.0
# 2            Robin van Persie             89               89    30000000.0
# 3               Sergio Agüero             88               90    42000000.0
# 4      Bastian Schweinsteiger             88               88    27500000.0
# ...                       ...            ...              ...           ...
# 11202           Matthieu Udol             68               75     1100000.0
# 11203          Felix Passlack             68               78     1400000.0
# 11204          Andrea Favilli             68               78     1500000.0
# 11205         Hidde ter Avest             68               76     1200000.0
# 11206            Oliver Burke             68               73     1200000.0
#
#        Weekly Salary  Height  Weight  Age  Preferred Foot    id  games  time  \
# 0           450000.0     169      67   27               1  2097     38  3374
# 1           325000.0     185      80   29               0  2371     35  3103
# 2           240000.0     187      71   31               1  4387     27  2126
# 3           190000.0     172      74   26               0   619     33  2551
# 4           180000.0     183      79   30               0   907     20  1361
# ...              ...     ...     ...  ...             ...   ...    ...   ...
# 11202         5900.0     178      68   24               1  5745     10   797
# 11203        17000.0     170      74   22               0  2663      6   343
# 11204         6500.0     191      78   23               1  1997      7   267
# 11205         5300.0     182      78   23               0  7000      6   348
# 11206        15500.0     188      82   23               0  5256     12   752
#
#        goals         xG  assists         xA  shots  key_passes  yellow_cards  \
# 0         43  35.891764       18  17.611956    187          95             4
# 1         48  39.308761       16  13.600642    225          76             5
# 2         10  11.603472        2   2.986052     76          27             5
# 3         26  25.270160        8   5.568922    148          33             4
# 4          5   2.174514        4   2.219083     29          31             4
# ...      ...        ...      ...        ...    ...         ...           ...
# 11202      0   0.063979        1   1.524224      3          10             1
# 11203      1   0.510328        0   0.240143      5           3             0
# 11204      2   1.872083        0   0.112031     13           2             1
# 11205      0   0.000000        0   0.000000      0           0             0
# 11206      0   1.377128        1   2.462660     16          13             2
#
#        red_cards  npg       npxG    xGChain  xGBuildup  year
# 0              0   38  31.432098  54.753610  19.756724  2014
# 1              1   38  30.389686  43.608020   7.520237  2014
# 2              0    9  10.081134  12.917514   1.688729  2014
# 3              0   21  20.703184  27.805155   6.878173  2014
# 4              0    5   2.174514   7.016763   4.264381  2014
# ...          ...  ...        ...        ...        ...   ...
# 11202          1    0   0.063979   2.182267   0.692643  2020
# 11203          0    1   0.510328   1.801331   1.050860  2020
# 11204          0    2   1.872083   2.520636   0.638041  2020
# 11205          0    0   0.000000   1.647105   1.647105  2020
# 11206          0    0   1.377128   4.340086   0.500298  2020
#
# [11207 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11207 entries, 0 to 11206
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player           11207 non-null  object
#  1   Overall Score    11207 non-null  int64
#  2   Potential Score  11207 non-null  int64
#  3   Market Value     11207 non-null  float64
#  4   Weekly Salary    11207 non-null  float64
#  5   Height           11207 non-null  int64
#  6   Weight           11207 non-null  int64
#  7   Age              11207 non-null  int64
#  8   Preferred Foot   11207 non-null  int64
#  9   id               11207 non-null  int64
#  10  games            11207 non-null  int64
#  11  time             11207 non-null  int64
#  12  goals            11207 non-null  int64
#  13  xG               11207 non-null  float64
#  14  assists          11207 non-null  int64
#  15  xA               11207 non-null  float64
#  16  shots            11207 non-null  int64
#  17  key_passes       11207 non-null  int64
#  18  yellow_cards     11207 non-null  int64
#  19  red_cards        11207 non-null  int64
#  20  npg              11207 non-null  int64
#  21  npxG             11207 non-null  float64
#  22  xGChain          11207 non-null  float64
#  23  xGBuildup        11207 non-null  float64
#  24  year             11207 non-null  int64
# dtypes: float64(7), int64(17), object(1)
# memory usage: 2.1+ MB

# %%
df2 = df.drop("Player", axis=1)
scaler = StandardScaler()
dataset_scaled = scaler.fit_transform(df2)
df2.hist(figsize = (16,16))
# Out:
# array([[<AxesSubplot:title={'center':'Overall Score'}>,
#         <AxesSubplot:title={'center':'Potential Score'}>,
#         <AxesSubplot:title={'center':'Market Value'}>,
#         <AxesSubplot:title={'center':'Weekly Salary'}>,
#         <AxesSubplot:title={'center':'Height'}>],
#        [<AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Preferred Foot'}>,
#         <AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'games'}>],
#        [<AxesSubplot:title={'center':'time'}>,
#         <AxesSubplot:title={'center':'goals'}>,
#         <AxesSubplot:title={'center':'xG'}>,
#         <AxesSubplot:title={'center':'assists'}>,
#         <AxesSubplot:title={'center':'xA'}>],
#        [<AxesSubplot:title={'center':'shots'}>,
#         <AxesSubplot:title={'center':'key_passes'}>,
#         <AxesSubplot:title={'center':'yellow_cards'}>,
#         <AxesSubplot:title={'center':'red_cards'}>,
#         <AxesSubplot:title={'center':'npg'}>],
#        [<AxesSubplot:title={'center':'npxG'}>,
#         <AxesSubplot:title={'center':'xGChain'}>,
#         <AxesSubplot:title={'center':'xGBuildup'}>,
#         <AxesSubplot:title={'center':'year'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.hist(df.Age, bins=100)
plt.xlabel("Age")
plt.ylabel("Number of players")
# Out:
# Text(0, 0.5, 'Number of players')

# %%
sns.boxplot(df["games"])
pd.options.mode.chained_assignment = None
# Out:
# /swst/apps/anaconda3/2021.05_gcc-8.5.0/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Preferred Foot'].value_counts().plot(kind='pie')
print("0      Right Preferred Foot")
print("1       Left Preferred Foot")
# Out:
# 0      Right Preferred Foot
# 1       Left Preferred Foot

# %%
df["year"].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='year'>

# %%
df['Market Value'] = df['Market Value']/100

# %%
data=df.groupby(['Overall Score']).mean()[['Weekly Salary', 'Market Value']]
data.plot()
# Out:
# <AxesSubplot:xlabel='Overall Score'>

# %%
df['Market Value'] = df['Market Value']*100

# %%
data=df.groupby(['Overall Score']).mean()[['goals','assists','xGBuildup']]
data.plot()data=df.groupby(['Age']).mean()[['key_passes', 'shots', 'xGChain']]
data.plot()
# Out:
# <AxesSubplot:xlabel='Overall Score'>

# %%
data=df.groupby(['Age']).mean()[['key_passes', 'shots', 'xGChain']]
data.plot()
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df.groupby('Weekly Salary').Age.mean()
data = df.groupby(['Weekly Salary']).mean()[['Age', 'Overall Score']].plot(kind='line')  #kind=line is used in order to obtain a line plot
plt.ylabel('Overall Score Mean')
# Out:
# Text(0, 0.5, 'Overall Score Mean')

# %%
ax = sns.kdeplot(df["Overall Score"], shade=True)
sns.kdeplot(df["Potential Score"], shade=True)
# Out:
# <AxesSubplot:xlabel='Overall Score', ylabel='Density'>

# %%
data2 = pd.DataFrame(df, columns = ['Market Value', 'Overall Score', 'assists', 'npg', 'goals', 'shots'])
sns.heatmap(data2.corr(), annot=True, linewidth=0.5)
# Out:
# /swst/apps/anaconda3/2021.05_gcc-8.5.0/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2264: RuntimeWarning: coroutine 'main' was never awaited
#   for k, v in kwargs.items():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# <AxesSubplot:>

# %%
data3 = pd.DataFrame(df, columns = ['Weekly Salary', 'Age', 'xGChain', 'time', 'xGBuildup'])
sns.heatmap(data3.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
GoalsPerMin = df.goals / df.time
df['GoalsPerMin'] = GoalsPerMin
sns.heatmap(df.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
colormap = sns.color_palette("Greens") 
data4 = pd.DataFrame(df, columns = ['Market Value', 'Age', 'Height', 'Weight'])
sns.heatmap(data4.corr(), annot=True, cmap=colormap)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df, x="Market Value", y="Weekly Salary", hue="Overall Score")
# Out:
# <AxesSubplot:xlabel='Market Value', ylabel='Weekly Salary'>

# %%
sns.scatterplot(data=df, x="key_passes", y="xGChain", hue="Market Value")
# Out:
# <AxesSubplot:xlabel='key_passes', ylabel='xGChain'>

# %%
sns.scatterplot(data=df, x="goals", y="xGChain", hue="Market Value")
# Out:
# <AxesSubplot:xlabel='goals', ylabel='xGChain'>

# %%
sns.scatterplot(data=df, x="goals", y="shots", hue="Overall Score")
# Out:
# <AxesSubplot:xlabel='goals', ylabel='shots'>

# %%
from mpl_toolkits.mplot3d import Axes3D # noqa: F401 unused import
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(8,6)) 
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['key_passes'], df['year'], df['Market Value'] , c='navy')

ax.set_xlabel('Key passes') 
ax.set_ylabel('Assists') 
ax.set_zlabel('Market Value')

plt.show()

# %%
df[['Weekly Salary', 'time', 'goals']].corr()
# Out:
#                Weekly Salary      time     goals
# Weekly Salary       1.000000  0.144049  0.350158
# time                0.144049  1.000000  0.357969
# goals               0.350158  0.357969  1.000000

# %%
df[['goals', 'xG']].corr()
# Out:
#           goals        xG
# goals  1.000000  0.943929
# xG     0.943929  1.000000

# %%
fig, ax = plt.subplots(figsize=(10,7))  
data3 = pd.DataFrame(df, columns = ['Market Value', 'time', 'goals', 'assists', 'xG', 'xA', 'key_passes', 'shots', 'npg', 'npxG', 'xGChain', 'xGBuildup'])
sns.heatmap(data3.corr(), annot=True, cmap='YlGnBu', linewidths=1)
# Out:
# <AxesSubplot:>
